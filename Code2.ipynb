# %%
# take second element for sort
def takeSecond(elem):
    return elem[1]

# to check availability of seats
def check(C_no_seats , detail):
    
    choice1 = detail[2]-1 # choice shows college no.
    choice2 = detail[3]-1
    choice3 = detail[4]-1
    
    if C_no_seats[choice1] > 0:
        C_no_seats[choice1] -= 1
        return detail[2]
    elif C_no_seats[choice2] > 0:
        C_no_seats[choice2] -= 1
        return detail[3]
    elif C_no_seats[choice3] > 0:
        C_no_seats[choice3] -= 1
        return detail[4]
    
    return 0

inp = list(map(int, input().split()))
C = inp[0]      # no. of college
N = inp[1]      # no. of students
C_no_of_seats = list(map(int, input().split()))
N_student = []

for i in range(0 , N , 1):
    id1 = int(input())
    per = float(input())
    int_per = int(per * 100)
    c1 = int(input())
    c2 = int(input())
    c3 = int(input())
    N_student.append([id1,int_per,c1,c2,c3])
    
N_student.sort(key=takeSecond)
N_student.reverse()

output = []

for i in range(0 , N , 1):
    temp = N_student[i]
    result = check(C_no_of_seats , temp)
    id = temp[0]
    
    if result != 0:
        print(f"Student-{id} C-{result}")
# Out:
# 3 5
# 3 1 2
# 1
# 97.50
# 1
# 3
# 2
# 2
# 48.03
# 1
# 2
# 3
# 3
# 85.69
# 1
# 2
# 3
# 4
# 80.83
# 1
# 3
# 2
# 5
# 89
# 2
# 3
# 1
# Student-1 C-1
# Student-5 C-2
# Student-3 C-1
# Student-4 C-1
# Student-2 C-3
